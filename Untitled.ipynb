# %%
my_list = [1,2,3]

# %%
my_list = ['STRING',100,2.3]

# %%
len(my_list)
# Out:
# 3

# %%
my_list[1]
# Out:
# 100

# %%
my_list
# Out:
# ['STRING', 100, 2.3]

# %%
another_list = ["yash","is","good","boy"]

# %%
my_list + another_list
# Out:
# ['STRING', 100, 2.3, 'yash', 'is', 'good', 'boy']

# %%
another_list
# Out:
# ['yash', 'is', 'good', 'boy']

# %%
my_list.reverse()

# %%
my_list.pop()
# Out:
# 2.3

# %%
list = ['a','b','c']

# %%
list[2]
# Out:
# 'c'

# %%
list[2].upper()
# Out:
# 'C'

# %%
1 > 2
# Out:
# False

# %%
 500 > 499
# Out:
# True

# %%
2+1
# Out:
# 3

# %%
suger = 40 
tea_powder = 20
gas = 2
other_things = 5

# %%
total_cost_to_run = suger+tea_powder+gas+other_things

# %%
# Out:
# '402025'

# %%
total_cost_to_run

# %%
margine = 500 + total_cost_to_run
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 margine = 500+total_cost_to_run
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
my_taxes
# Out:
# 100.1

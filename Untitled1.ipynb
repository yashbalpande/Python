# %%
# %%writefile weo.txt
# this is my frist text file
# Out:
# Writing weo.txt

# %%
weo = open("weo.txt")

# %%
pwd
# Out:
# 'C:\\Users\\yashb\\Desktop\\New folder'

# %%
weo.read()
# Out:
# 'this is my frist text file\n'

# %%
weo.edit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 weo.edit()
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'edit'

# %%
weo.write()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 weo.write()
#
# TypeError: TextIOWrapper.write() takes exactly one argument (0 given)
